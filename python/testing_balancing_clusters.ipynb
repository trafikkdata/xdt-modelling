# %%
from pathlib import Path

import pandas as pd

from python.balancing.cluster_on_prelim_aadt import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       3 import pandas as pd
#       5 from python import utilities
# ----> 6 from python.balancing.cluster_on_prelim_aadt import *
#
# File c:\Users\EMMSKA\Documents\GitHub\xdt-modelling\python\balancing\cluster_on_prelim_aadt.py:7
#       5 import pandas as pd
#       6 import networkx as nx
# ----> 7 from utilities import build_graph_from_geojson_as_dictionary
#      10 def add_cluster_id_to_df(df: pd.DataFrame, geojson_data: dict) -> pd.DataFrame:
#      11     """
#      12     Add a cluster ID to the DataFrame based on the cluster ID map.
#      13
#    (...)
#      18         pd.DataFrame: The updated DataFrame with added cluster IDs.
#      19     """
#
# ModuleNotFoundError: No module named 'utilities'
